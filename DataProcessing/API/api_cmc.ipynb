# %%
from coinmarketcap import Market

# %%
coinmarketcap = Market()
coinmarketcap.listings()
# Out:
# {'attention': 'WARNING: This API is now deprecated and will be taken offline soon.  Please switch to the new CoinMarketCap API to avoid interruptions in service. (https://pro.coinmarketcap.com/migrate/)',
#  'data': [{'id': 1,
#    'name': 'Bitcoin',
#    'symbol': 'BTC',
#    'website_slug': 'bitcoin'},
#   {'id': 2, 'name': 'Litecoin', 'symbol': 'LTC', 'website_slug': 'litecoin'},
#   {'id': 3, 'name': 'Namecoin', 'symbol': 'NMC', 'website_slug': 'namecoin'},
#   {'id': 4, 'name': 'Terracoin', 'symbol': 'TRC', 'website_slug': 'terracoin'},
#   {'id': 5, 'name': 'Peercoin', 'symbol': 'PPC', 'website_slug': 'peercoin'},
#   {'id': 6, 'name': 'Novacoin', 'symbol': 'NVC', 'website_slug': 'novacoin'},
#   {'id': 8,
#    'name': 'Feathercoin',
#    'symbol': 'FTC',
#    'website_slug': 'feathercoin'},
#   {'id': 9, 'name': 'Mincoin', 'symbol': 'MNC', 'website_slug': 'mincoin'},
#   {'id': 10, 'name': 'Freicoin', 'symbol': 'FRC', 'website_slug': 'freicoin'},
# ...

# %%
coinmarketcap.ticker(start=0, limit=3, convert='EUR', sort='rank')['data']['1027']
# Out:
# {'id': 1027,
#  'name': 'Ethereum',
#  'symbol': 'ETH',
#  'website_slug': 'ethereum',
#  'rank': 2,
#  'circulating_supply': 104253660.0,
#  'total_supply': 104253660.0,
#  'max_supply': None,
#  'quotes': {'USD': {'price': 149.582853571,
#    'volume_24h': 2692934830.72447,
#    'market_cap': 15594559935.0,
#    'percent_change_1h': -0.95,
#    'percent_change_24h': -4.32,
#    'percent_change_7d': 11.61},
#   'EUR': {'price': 130.6236756294,
#    'volume_24h': 2351613419.7346373,
#    'market_cap': 13617996246.0,
#    'percent_change_1h': -0.95,
#    'percent_change_24h': -4.32,
#    'percent_change_7d': 11.61}},
#  'last_updated': 1546916838}

# %%
coinmarketcap.ticker(1, convert='EUR')
# Out:
# {'attention': 'WARNING: This API is now deprecated and will be taken offline soon.  Please switch to the new CoinMarketCap API to avoid interruptions in service. (https://pro.coinmarketcap.com/migrate/)',
#  'data': {'id': 1,
#   'name': 'Bitcoin',
#   'symbol': 'BTC',
#   'website_slug': 'bitcoin',
#   'rank': 1,
#   'circulating_supply': 17469137.0,
#   'total_supply': 17469137.0,
#   'max_supply': 21000000.0,
#   'quotes': {'USD': {'price': 4010.13811749,
#     'volume_24h': 5172959448.25562,
#     'market_cap': 70053652163.0,
#     'percent_change_1h': -0.14,
#     'percent_change_24h': -1.42,
#     'percent_change_7d': 7.09},
#    'EUR': {'price': 3502.2260539431,
#     'volume_24h': 4517767923.417922,
#     'market_cap': 61180866741.0,
#     'percent_change_1h': -0.14,
#     'percent_change_24h': -1.42,
#     'percent_change_7d': 7.09}},
#   'last_updated': 1546917088},
#  'metadata': {'timestamp': 1546916209,
# ...
