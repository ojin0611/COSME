# %% [markdown]
# # WOODBURY

# %%
from bs4 import BeautifulSoup as bs              # 데이터파싱 라이브러리
from selenium import webdriver
import json
import re
import platform

# %%
def getNumber(string):
    numExtracter = re.compile('[0-9]+')
    return int(''.join(numExtracter.findall(string)))

# %%
def getPrdCount(driver):
    html = driver.page_source
    soup = bs(html,'lxml')
    prdCount = soup.find('p',{'class':'prdCount'})
    
    return getNumber(prdCount.get_text())

# %%
def getItems(category, categoryname):
    driver.find_element_by_id(category).click()
    
    productsImages = driver.find_elements_by_class_name('prdImg')
    total_len = len(productsImages)
    prdCount = getPrdCount(driver)
    
    result_json = []
    
    for i in range(total_len - prdCount, total_len):
        result_dict = {'name':'#', 'url':'#', 'image':'#', 'color':'#', 'category':categoryname, 
                   'salePrice':'#', 'originalPrice':'#', 'brand':'woodbury','volume':'#'}
        productsImages = driver.find_elements_by_class_name('prdImg')
        productsImages[i].click()

        html = driver.page_source
        soup = bs(html,'lxml')

        # 상품명, 가격 적힌 태그 뽑기
        tags = soup.find_all('tr',{'class':'xans-record-'})
        
        for tag in tags:
            if '상품명' in tag.get_text().strip():
                result_dict['name'] = tag.get_text().strip()[4:]
                
            elif '소비자가' in tag.get_text().strip():
                result_dict['originalPrice'] = getNumber(tag.get_text().strip()[5:])

            elif '판매가' in tag.get_text().strip():
                result_dict['salePrice'] = getNumber(tag.get_text().strip()[4:])
                if result_dict['originalPrice'] == '#':
                    result_dict['originalPrice'] = getNumber(tag.get_text().strip()[4:])
            
        # url, image 
        result_dict['url']  = driver.current_url
        result_dict['image'] = 'http:'+ soup.find_all('img',{'class':'BigImage'})[0]['src']
        
        # 색깔 개수만큼 output
        for j, item in enumerate(soup.find_all('option')):
            if j>1:
                color = ''.join(str(item.find(text=True)))
                if '-----' in color:
                    continue
                result_dict = result_dict.copy()
                result_dict['color'] = color 
                result_json.append(result_dict)

        driver.find_element_by_id(category).click()
        
    display(result_json)
    return result_json

# %%
def writeJSON(jsonString, output_name='data.json'):
    with open(output_name,'w',encoding='UTF-8') as file:
        file.write(jsonString)

# %%
path = 'chromedriver.exe' if (platform.system() == 'Windows') else '/Users/jg/Desktop/develop/DataTeam/DataProcessing/product/crawling/chromedriver';
driver = webdriver.Chrome(path)

# %%
driver.get("http://woodbury.co.kr/")

# %%
eyeLiner = 'cate_img_45'
eyeBrow = 'cate_img_46'
lipPencilTint = 'cate_img_49'
Mascara = 'cate_img_50'
baseMakeUp = 'cate_img_87'
concealer = 'cate_img_82'
accessory = 'cate_img_48'

# %%
result = []
result += getItems(eyeLiner,'아이라이너')
result += getItems(eyeBrow,'아이브로우')
result += getItems(lipPencilTint,'립펜슬, 틴트')
result += getItems(Mascara,'마스카라')
result += getItems(baseMakeUp,'베이스 메이크업')
result += getItems(concealer,'컨실러')
result += getItems(accessory,'악세서리')
# Out:
# [{'name': '엑스트라아시아 오토라이너',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=57&cate_no=45&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201811/abb4fa6f6aa899b29ad107ff34101a19.jpg',
#   'color': '블랙',
#   'category': '아이라이너',
#   'salePrice': 12000,
#   'originalPrice': 12000,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '엑스트라아시아 오토라이너',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=57&cate_no=45&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201811/abb4fa6f6aa899b29ad107ff34101a19.jpg',
#   'color': '쥬얼브라운',
#   'category': '아이라이너',
#   'salePrice': 12000,
#   'originalPrice': 12000,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '엑스트라아시아 오토라이너',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=57&cate_no=45&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201811/abb4fa6f6aa899b29ad107ff34101a19.jpg',
#   'color': '핑크베이지',
#   'category': '아이라이너',
#   'salePrice': 12000,
#   'originalPrice': 12000,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '엑스트라아시아 오토라이너',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=57&cate_no=45&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201811/abb4fa6f6aa899b29ad107ff34101a19.jpg',
#   'color': '스태리브라운',
#   'category': '아이라이너',
#   'salePrice': 12000,
#   'originalPrice': 12000,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '크리미젤슈퍼슬림 오토아이라이너',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=46&cate_no=45&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201901/9059992926dcf12d199b10b33ae32f6e.jpg',
#   'color': '블랙',
#   'category': '아이라이너',
#   'salePrice': 14000,
#   'originalPrice': 14000,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '크리미젤슈퍼슬림 오토아이라이너',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=46&cate_no=45&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201901/9059992926dcf12d199b10b33ae32f6e.jpg',
#   'color': '브라운',
#   'category': '아이라이너',
#   'salePrice': 14000,
#   'originalPrice': 14000,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '우드버리 UHD 롱앤롱브러쉬라이너',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=44&cate_no=45&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201509/44_shop1_956966.jpg',
#   'color': '블랙',
#   'category': '아이라이너',
#   'salePrice': 16000,
#   'originalPrice': 16000,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '우드버리 UHD 롱앤롱브러쉬라이너',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=44&cate_no=45&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201509/44_shop1_956966.jpg',
#   'color': '브라운',
#   'category': '아이라이너',
#   'salePrice': 16000,
#   'originalPrice': 16000,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '컬러스팟 리퀴드 아이라이너',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=29&cate_no=45&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201509/29_shop1_850260.jpg',
#   'color': '핫블랙',
#   'category': '아이라이너',
#   'salePrice': 14000,
#   'originalPrice': 14000,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '컬러스팟 리퀴드 아이라이너',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=29&cate_no=45&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201509/29_shop1_850260.jpg',
#   'color': '핫초콜렛',
#   'category': '아이라이너',
#   'salePrice': 14000,
#   'originalPrice': 14000,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '컬러스팟 리퀴드 아이라이너',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=29&cate_no=45&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201509/29_shop1_850260.jpg',
#   'color': '스위트브라운',
#   'category': '아이라이너',
#   'salePrice': 14000,
#   'originalPrice': 14000,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': 'HD아쿠아젤',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=27&cate_no=45&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201509/27_shop1_410177.jpg',
#   'color': '브라운',
#   'category': '아이라이너',
#   'salePrice': 9700,
#   'originalPrice': 9700,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': 'HD아쿠아젤',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=27&cate_no=45&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201509/27_shop1_410177.jpg',
#   'color': '다크브라운',
#   'category': '아이라이너',
#   'salePrice': 9700,
#   'originalPrice': 9700,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '이집시안3D펄 아이라이너',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=24&cate_no=45&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201509/24_shop1_798799.jpg',
#   'color': '블랙',
#   'category': '아이라이너',
#   'salePrice': 9700,
#   'originalPrice': 9700,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '이집시안3D펄 아이라이너',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=24&cate_no=45&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201509/24_shop1_798799.jpg',
#   'color': '브라운',
#   'category': '아이라이너',
#   'salePrice': 9700,
#   'originalPrice': 9700,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '파워업그레이드펜슬',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=23&cate_no=45&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201509/23_shop1_601255.jpg',
#   'color': '폴인아이즈',
#   'category': '아이라이너',
#   'salePrice': 9700,
#   'originalPrice': 9700,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '파워업그레이드펜슬',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=23&cate_no=45&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201509/23_shop1_601255.jpg',
#   'color': '펄리브라운',
#   'category': '아이라이너',
#   'salePrice': 9700,
#   'originalPrice': 9700,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '파워업그레이드펜슬',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=23&cate_no=45&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201509/23_shop1_601255.jpg',
#   'color': '샴페인',
#   'category': '아이라이너',
#   'salePrice': 9700,
#   'originalPrice': 9700,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '스테이24',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=21&cate_no=45&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201509/21_shop1_543999.jpg',
#   'color': '룩스브라운',
#   'category': '아이라이너',
#   'salePrice': 11000,
#   'originalPrice': 11000,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '스테이24',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=21&cate_no=45&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201509/21_shop1_543999.jpg',
#   'color': '블랙',
#   'category': '아이라이너',
#   'salePrice': 11000,
#   'originalPrice': 11000,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '스테이24',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=21&cate_no=45&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201509/21_shop1_543999.jpg',
#   'color': '브라운',
#   'category': '아이라이너',
#   'salePrice': 11000,
#   'originalPrice': 11000,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '스테이24',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=21&cate_no=45&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201509/21_shop1_543999.jpg',
#   'color': '골든브라운',
#   'category': '아이라이너',
#   'salePrice': 11000,
#   'originalPrice': 11000,
#   'brand': 'woodbury',
#   'volume': '#'}]
# [{'name': '벨벳 듀오 브로우',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=58&cate_no=46&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201811/08df18a4f33e88d129cc4ee0bf668f3b.jpg',
#   'color': '애쉬브라운',
#   'category': '아이브로우',
#   'salePrice': 14000,
#   'originalPrice': 14000,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '벨벳 듀오 브로우',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=58&cate_no=46&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201811/08df18a4f33e88d129cc4ee0bf668f3b.jpg',
#   'color': '초코브라운',
#   'category': '아이브로우',
#   'salePrice': 14000,
#   'originalPrice': 14000,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '벨벳 듀오 브로우',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=58&cate_no=46&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201811/08df18a4f33e88d129cc4ee0bf668f3b.jpg',
#   'color': '다크브라운',
#   'category': '아이브로우',
#   'salePrice': 14000,
#   'originalPrice': 14000,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '우드버리 하드텍스처 아이브로우',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=45&cate_no=46&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201901/12704e2684ca6b1f59033f52b4b9eccb.jpg',
#   'color': '하바나브라운',
#   'category': '아이브로우',
#   'salePrice': 11200,
#   'originalPrice': 14000,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '우드버리 하드텍스처 아이브로우',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=45&cate_no=46&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201901/12704e2684ca6b1f59033f52b4b9eccb.jpg',
#   'color': '로즈브라운',
#   'category': '아이브로우',
#   'salePrice': 11200,
#   'originalPrice': 14000,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '우드버리 하드텍스처 아이브로우',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=45&cate_no=46&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201901/12704e2684ca6b1f59033f52b4b9eccb.jpg',
#   'color': '팀버올프',
#   'category': '아이브로우',
#   'salePrice': 11200,
#   'originalPrice': 14000,
#   'brand': 'woodbury',
#   'volume': '#'}]
# [{'name': '샤인 허그 리퀴드 립',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=55&cate_no=49&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201811/0e91ef0f1ea8ecf58d2f3ab0b546b3c0.jpg',
#   'color': '비바핑크',
#   'category': '립펜슬, 틴트',
#   'salePrice': 16000,
#   'originalPrice': 16000,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '샤인 허그 리퀴드 립',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=55&cate_no=49&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201811/0e91ef0f1ea8ecf58d2f3ab0b546b3c0.jpg',
#   'color': '로지누드',
#   'category': '립펜슬, 틴트',
#   'salePrice': 16000,
#   'originalPrice': 16000,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '샤인 허그 리퀴드 립',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=55&cate_no=49&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201811/0e91ef0f1ea8ecf58d2f3ab0b546b3c0.jpg',
#   'color': '체리엠버',
#   'category': '립펜슬, 틴트',
#   'salePrice': 16000,
#   'originalPrice': 16000,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '샤인 허그 리퀴드 립',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=55&cate_no=49&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201811/0e91ef0f1ea8ecf58d2f3ab0b546b3c0.jpg',
#   'color': '플럼레드',
#   'category': '립펜슬, 틴트',
#   'salePrice': 16000,
#   'originalPrice': 16000,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '샤인 허그 리퀴드 립',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=55&cate_no=49&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201811/0e91ef0f1ea8ecf58d2f3ab0b546b3c0.jpg',
#   'color': '샬롯레드',
#   'category': '립펜슬, 틴트',
#   'salePrice': 16000,
#   'originalPrice': 16000,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '울트라 HD 스무디 벨벳 틴트',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=48&cate_no=49&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201701/48_shop1_446198.jpg',
#   'color': '코랄핑크',
#   'category': '립펜슬, 틴트',
#   'salePrice': 8800,
#   'originalPrice': 11000,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '울트라 HD 스무디 벨벳 틴트',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=48&cate_no=49&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201701/48_shop1_446198.jpg',
#   'color': '딥캐롯',
#   'category': '립펜슬, 틴트',
#   'salePrice': 8800,
#   'originalPrice': 11000,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '울트라 HD 스무디 벨벳 틴트',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=48&cate_no=49&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201701/48_shop1_446198.jpg',
#   'color': '레드와인',
#   'category': '립펜슬, 틴트',
#   'salePrice': 8800,
#   'originalPrice': 11000,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '울트라 HD 스무디 벨벳 틴트',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=48&cate_no=49&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201701/48_shop1_446198.jpg',
#   'color': '스칼렛로즈',
#   'category': '립펜슬, 틴트',
#   'salePrice': 8800,
#   'originalPrice': 11000,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '울트라 HD 스무디 벨벳 틴트',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=48&cate_no=49&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201701/48_shop1_446198.jpg',
#   'color': '딥레드',
#   'category': '립펜슬, 틴트',
#   'salePrice': 8800,
#   'originalPrice': 11000,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '울트라 HD 스무디 벨벳 틴트',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=48&cate_no=49&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201701/48_shop1_446198.jpg',
#   'color': '루비레드',
#   'category': '립펜슬, 틴트',
#   'salePrice': 8800,
#   'originalPrice': 11000,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '울트라 HD 스무디 벨벳 틴트',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=48&cate_no=49&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201701/48_shop1_446198.jpg',
#   'color': '스윗로즈',
#   'category': '립펜슬, 틴트',
#   'salePrice': 8800,
#   'originalPrice': 11000,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '울트라 HD 스무디 벨벳 틴트',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=48&cate_no=49&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201701/48_shop1_446198.jpg',
#   'color': '브릭로즈',
#   'category': '립펜슬, 틴트',
#   'salePrice': 8800,
#   'originalPrice': 11000,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '퍼펙트 울트라 립펜슬 벨벳매트',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=33&cate_no=49&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201509/33_shop1_450965.jpg',
#   'color': '와일드베리',
#   'category': '립펜슬, 틴트',
#   'salePrice': 16800,
#   'originalPrice': 16800,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '퍼펙트 울트라 립펜슬 벨벳매트',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=33&cate_no=49&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201509/33_shop1_450965.jpg',
#   'color': '레드누보',
#   'category': '립펜슬, 틴트',
#   'salePrice': 16800,
#   'originalPrice': 16800,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '퍼펙트 울트라 립펜슬 벨벳매트',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=33&cate_no=49&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201509/33_shop1_450965.jpg',
#   'color': '레드오렌지',
#   'category': '립펜슬, 틴트',
#   'salePrice': 16800,
#   'originalPrice': 16800,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '퍼펙트 울트라 립펜슬 벨벳매트',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=33&cate_no=49&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201509/33_shop1_450965.jpg',
#   'color': '슈가로즈',
#   'category': '립펜슬, 틴트',
#   'salePrice': 16800,
#   'originalPrice': 16800,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '퍼펙트 울트라 립펜슬 벨벳매트',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=33&cate_no=49&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201509/33_shop1_450965.jpg',
#   'color': '스칼렛레드',
#   'category': '립펜슬, 틴트',
#   'salePrice': 16800,
#   'originalPrice': 16800,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '퍼펙트 울트라 립펜슬 벨벳매트',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=33&cate_no=49&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201509/33_shop1_450965.jpg',
#   'color': '트루레드',
#   'category': '립펜슬, 틴트',
#   'salePrice': 16800,
#   'originalPrice': 16800,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '퍼펙트 울트라 립펜슬 벨벳매트',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=33&cate_no=49&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201509/33_shop1_450965.jpg',
#   'color': '코랄레드',
#   'category': '립펜슬, 틴트',
#   'salePrice': 16800,
#   'originalPrice': 16800,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '퍼펙트 울트라 립펜슬 새틴',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=32&cate_no=49&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201509/32_shop1_896448.jpg',
#   'color': '레드루비',
#   'category': '립펜슬, 틴트',
#   'salePrice': 16800,
#   'originalPrice': 16800,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '퍼펙트 울트라 립펜슬 새틴',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=32&cate_no=49&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201509/32_shop1_896448.jpg',
#   'color': '로즈핑크',
#   'category': '립펜슬, 틴트',
#   'salePrice': 16800,
#   'originalPrice': 16800,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '퍼펙트 울트라 립펜슬 새틴',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=32&cate_no=49&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201509/32_shop1_896448.jpg',
#   'color': '버건디레드',
#   'category': '립펜슬, 틴트',
#   'salePrice': 16800,
#   'originalPrice': 16800,
#   'brand': 'woodbury',
#   'volume': '#'}]
# []
# [{'name': '시크 글로우 워터 쿠션',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=56&cate_no=87&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201901/3fe567a2cff89b74448f4f0c9bda6470.jpg',
#   'color': '핑크베이지21호',
#   'category': '베이스 메이크업',
#   'salePrice': 225002500,
#   'originalPrice': 25000,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '시크 글로우 워터 쿠션',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=56&cate_no=87&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201901/3fe567a2cff89b74448f4f0c9bda6470.jpg',
#   'color': '미디엄베이지23호',
#   'category': '베이스 메이크업',
#   'salePrice': 225002500,
#   'originalPrice': 25000,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '우드버리 Ultra HD 캐주얼워터 파운데이션',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=54&cate_no=87&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201901/8f32d78b6f4da8cf37a9727bc6e9670a.jpg',
#   'color': '워터 파운데이션21호',
#   'category': '베이스 메이크업',
#   'salePrice': 29000,
#   'originalPrice': 29000,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '우드버리 Ultra HD 캐주얼워터 파운데이션',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=54&cate_no=87&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201901/8f32d78b6f4da8cf37a9727bc6e9670a.jpg',
#   'color': '워터 파운데이션23호',
#   'category': '베이스 메이크업',
#   'salePrice': 29000,
#   'originalPrice': 29000,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '우드버리 워터 프라이머 파운데이션',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=51&cate_no=87&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201901/e7e2afdbbe2ecc6c17e54ead72a612a8.jpg',
#   'color': '21호',
#   'category': '베이스 메이크업',
#   'salePrice': 28000,
#   'originalPrice': 28000,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '우드버리 워터 프라이머 파운데이션',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=51&cate_no=87&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201901/e7e2afdbbe2ecc6c17e54ead72a612a8.jpg',
#   'color': '23호',
#   'category': '베이스 메이크업',
#   'salePrice': 28000,
#   'originalPrice': 28000,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '울트라 HD 스타일리시 쿠션',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=49&cate_no=87&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201701/49_shop1_333922.jpg',
#   'color': '로제 21호',
#   'category': '베이스 메이크업',
#   'salePrice': 28000,
#   'originalPrice': 28000,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '울트라 HD 스타일리시 쿠션',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=49&cate_no=87&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201701/49_shop1_333922.jpg',
#   'color': '베이지 23호',
#   'category': '베이스 메이크업',
#   'salePrice': 28000,
#   'originalPrice': 28000,
#   'brand': 'woodbury',
#   'volume': '#'}]
# [{'name': '울트라 HD 커버스테이 컨실러',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=47&cate_no=82&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201701/47_shop1_423581.jpg',
#   'color': '로제 21호',
#   'category': '컨실러',
#   'salePrice': 13000,
#   'originalPrice': 13000,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '울트라 HD 커버스테이 컨실러',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=47&cate_no=82&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201701/47_shop1_423581.jpg',
#   'color': '베이지 23호',
#   'category': '컨실러',
#   'salePrice': 13000,
#   'originalPrice': 13000,
#   'brand': 'woodbury',
#   'volume': '#'}]
# [{'name': '독일산 듀얼샤프너',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=43&cate_no=48&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201509/43_shop1_513655.jpg',
#   'color': '와일드베리',
#   'category': '악세서리',
#   'salePrice': 1900,
#   'originalPrice': 1900,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '독일산 듀얼샤프너',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=43&cate_no=48&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201509/43_shop1_513655.jpg',
#   'color': '레드누보',
#   'category': '악세서리',
#   'salePrice': 1900,
#   'originalPrice': 1900,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '독일산 듀얼샤프너',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=43&cate_no=48&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201509/43_shop1_513655.jpg',
#   'color': '레드오렌지',
#   'category': '악세서리',
#   'salePrice': 1900,
#   'originalPrice': 1900,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '독일산 듀얼샤프너',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=43&cate_no=48&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201509/43_shop1_513655.jpg',
#   'color': '네온베이지핑크',
#   'category': '악세서리',
#   'salePrice': 1900,
#   'originalPrice': 1900,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '독일산 듀얼샤프너',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=43&cate_no=48&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201509/43_shop1_513655.jpg',
#   'color': '슈가로즈',
#   'category': '악세서리',
#   'salePrice': 1900,
#   'originalPrice': 1900,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '독일산 듀얼샤프너',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=43&cate_no=48&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201509/43_shop1_513655.jpg',
#   'color': '스칼렛레드',
#   'category': '악세서리',
#   'salePrice': 1900,
#   'originalPrice': 1900,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '독일산 듀얼샤프너',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=43&cate_no=48&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201509/43_shop1_513655.jpg',
#   'color': '트루레드',
#   'category': '악세서리',
#   'salePrice': 1900,
#   'originalPrice': 1900,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '독일산 듀얼샤프너',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=43&cate_no=48&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201509/43_shop1_513655.jpg',
#   'color': '코랄레드',
#   'category': '악세서리',
#   'salePrice': 1900,
#   'originalPrice': 1900,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '독일산 듀얼샤프너',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=43&cate_no=48&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201509/43_shop1_513655.jpg',
#   'color': '핑크브라운',
#   'category': '악세서리',
#   'salePrice': 1900,
#   'originalPrice': 1900,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '독일산 듀얼샤프너',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=43&cate_no=48&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201509/43_shop1_513655.jpg',
#   'color': '체리레드(신색상)',
#   'category': '악세서리',
#   'salePrice': 1900,
#   'originalPrice': 1900,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '독일산 듀얼샤프너',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=43&cate_no=48&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201509/43_shop1_513655.jpg',
#   'color': '옵션선택',
#   'category': '악세서리',
#   'salePrice': 1900,
#   'originalPrice': 1900,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '독일산 듀얼샤프너',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=43&cate_no=48&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201509/43_shop1_513655.jpg',
#   'color': '핑크돌',
#   'category': '악세서리',
#   'salePrice': 1900,
#   'originalPrice': 1900,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '독일산 듀얼샤프너',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=43&cate_no=48&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201509/43_shop1_513655.jpg',
#   'color': '코랄리본',
#   'category': '악세서리',
#   'salePrice': 1900,
#   'originalPrice': 1900,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '독일산 듀얼샤프너',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=43&cate_no=48&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201509/43_shop1_513655.jpg',
#   'color': '피치캐러멜',
#   'category': '악세서리',
#   'salePrice': 1900,
#   'originalPrice': 1900,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '독일산 듀얼샤프너',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=43&cate_no=48&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201509/43_shop1_513655.jpg',
#   'color': '레드루비',
#   'category': '악세서리',
#   'salePrice': 1900,
#   'originalPrice': 1900,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '독일산 듀얼샤프너',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=43&cate_no=48&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201509/43_shop1_513655.jpg',
#   'color': '만다린레드',
#   'category': '악세서리',
#   'salePrice': 1900,
#   'originalPrice': 1900,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '독일산 듀얼샤프너',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=43&cate_no=48&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201509/43_shop1_513655.jpg',
#   'color': '로즈핑크',
#   'category': '악세서리',
#   'salePrice': 1900,
#   'originalPrice': 1900,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '독일산 듀얼샤프너',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=43&cate_no=48&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201509/43_shop1_513655.jpg',
#   'color': '버건디레드',
#   'category': '악세서리',
#   'salePrice': 1900,
#   'originalPrice': 1900,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '독일산 듀얼샤프너',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=43&cate_no=48&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201509/43_shop1_513655.jpg',
#   'color': '스프링핑크(신색상)',
#   'category': '악세서리',
#   'salePrice': 1900,
#   'originalPrice': 1900,
#   'brand': 'woodbury',
#   'volume': '#'},
#  {'name': '독일산 듀얼샤프너',
#   'url': 'http://woodbury.co.kr/product/detail.html?product_no=43&cate_no=48&display_group=1',
#   'image': 'http://woodbury.co.kr/web/product/big/201509/43_shop1_513655.jpg',
#   'color': '로지코랄(신색상)',
#   'category': '악세서리',
#   'salePrice': 1900,
#   'originalPrice': 1900,
#   'brand': 'woodbury',
#   'volume': '#'}]

# %%
output = json.dumps(result,ensure_ascii=False, indent='\t')

writeJSON(output, output_name = 'woodbury.json')
