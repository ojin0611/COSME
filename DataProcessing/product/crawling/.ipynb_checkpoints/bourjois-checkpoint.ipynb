# %% [markdown]
# # bourjois

# %%
from bs4 import BeautifulSoup as bs              # 데이터파싱 라이브러리
from selenium import webdriver
import json
import platform
import re
import time
import copy

# %%
def getNumber(string):
    numExtracter = re.compile('[0-9]+')
    return int(''.join(numExtracter.findall(string)))

# %%
def getCategoryList():
    html = driver.page_source
    soup = bs(html, 'html.parser')
    categories = soup.find('ul',{'id':'Category_Menu'}).find_all('li')
    categoryList = [url_home + category.a['href'] for category in categories]

    return categoryList

# %%
def readNextPage():
    html = driver.page_source
    soup = bs(html, 'html.parser')
    nextPage_url = soup.find('a',{'class':'fa-angle-right'})['href']
    if '#' in nextPage_url:
        raise
    driver.get(url_products + nextPage_url)

# %%
def getItemList():
    html = driver.page_source
    soup = bs(html, 'html.parser')
    items = soup.find('div',{'id':'Product_ListMenu'}).find('ul',{'class':'ProductList Column3'}).find_all('li')
    itemList=[]
    for item in items:
        itemList.append(url_home + item.a['href'])
    return itemList

# %%
def getItem():
    html = driver.page_source
    soup = bs(html, 'html.parser')

    name = soup.find('span',text='상품명').parent.parent.td.get_text().strip()
    images = soup.find('div',{'class':"xans-element- xans-product xans-product-addimage listImg"
                            }).ul.find_all('img',{'class':'ThumbImage'})
    imageList = ['http:'+image['src'] for image in images]

    category = soup.find('span',text='현재 위치').parent.ol.get_text().strip()
    
    volume = soup.find('td',text='용량')
    volume = volume.parent.get_text().strip()[2:].strip() if volume else '#'
    try:
        salePrice = getNumber(soup.find('strong',{'id':'span_product_price_text'}).get_text())
    except:
        salePrice = '#'
    originalPrice = soup.find('span',{'id':'span_product_price_custom'})
    originalPrice = getNumber(originalPrice.get_text()) if originalPrice else salePrice
    
    item={'name':'#', 'url':'#', 'image':'#', 'salePrice':'#', 'originalPrice':'#', 'color':'#', 
                       'category':'#', 'brand':'#','volume':'#'}
    item['name']  = name
    item['image'] = imageList
    item['category'] = ' > '.join(category.split())
    item['volume'] = volume
    item['salePrice'] = salePrice
    item['originalPrice']=originalPrice
    item['brand']='bourjois'
    item['url']=driver.current_url
    
    items=[]
    colors = soup.find('select',{'id':'product_option_id1'})
    if colors:
        colorList = []
        colors = soup.find('select',{'id':'product_option_id1'}).find_all('option')
        for color in colors:
            color = color.get_text().strip()
            if '필수' in color:
                continue
            if '------' in color:
                continue
            if '품절' in color:
                color = color[:color.find('[품절')].strip()
            item_copy = copy.deepcopy(item)
            item_copy['color'] = color
            items.append(item_copy)
    
    else:
        item['color']='#'
        items.append(item)
    display(items)
    return items

# %%
def writeJSON(jsonString, output_name='data.json'):
    with open(output_name,'w',encoding='UTF-8') as file:
        file.write(jsonString)

# %%
path = 'chromedriver.exe' if (platform.system() == 'Windows') else '/Users/jg/Desktop/develop/DataTeam/DataProcessing/product/crawling/chromedriver';
driver = webdriver.Chrome(path)

url_home = 'http://bourjois-mall.com'
url_products = 'http://bourjois-mall.com/product/list.html'

# %%
driver.get(url_products)

categoryList = getCategoryList()
result = []
for category in categoryList:
    driver.get(category)
    itemList = []
    while True:
        itemList += getItemList()
        try:
            readNextPage()
        except:
            break
    for item in itemList:
        driver.get(item)
        result += getItem()
# Out:
# [{'name': 'NEW 헬씨 믹스 비비크림',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=511&cate_no=24&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201805/511_shop1_395531.jpg'],
#   'salePrice': 33000,
#   'originalPrice': 33000,
#   'color': '01 라이트',
#   'category': '홈 > FACE',
#   'brand': 'bourjois',
#   'volume': '30ml'},
#  {'name': 'NEW 헬씨 믹스 비비크림',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=511&cate_no=24&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201805/511_shop1_395531.jpg'],
#   'salePrice': 33000,
#   'originalPrice': 33000,
#   'color': '02 미디움',
#   'category': '홈 > FACE',
#   'brand': 'bourjois',
#   'volume': '30ml'}]
# [{'name': 'NEW 헬씨 믹스 블러링 프라이머',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=510&cate_no=24&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201804/510_shop1_298585.jpg'],
#   'salePrice': 26000,
#   'originalPrice': 26000,
#   'color': '#',
#   'category': '홈 > FACE',
#   'brand': 'bourjois',
#   'volume': '20ml'}]
# [{'name': '브론징 파우더 델리스 드 뿌드르',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=484&cate_no=24&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201705/484_shop1_891043.jpg'],
#   'salePrice': 30000,
#   'originalPrice': 30000,
#   'color': '#',
#   'category': '홈 > FACE',
#   'brand': 'bourjois',
#   'volume': '#'}]
# [{'name': 'NEW 헬씨 믹스 생과일 컨실러',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=465&cate_no=24&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201701/465_shop1_332254.jpg'],
#   'salePrice': 19000,
#   'originalPrice': 19000,
#   'color': '51 Light 라이트',
#   'category': '홈 > FACE',
#   'brand': 'bourjois',
#   'volume': '7.8ml'},
#  {'name': 'NEW 헬씨 믹스 생과일 컨실러',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=465&cate_no=24&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201701/465_shop1_332254.jpg'],
#   'salePrice': 19000,
#   'originalPrice': 19000,
#   'color': '52 Medium 미디움',
#   'category': '홈 > FACE',
#   'brand': 'bourjois',
#   'volume': '7.8ml'},
#  {'name': 'NEW 헬씨 믹스 생과일 컨실러',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=465&cate_no=24&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201701/465_shop1_332254.jpg'],
#   'salePrice': 19000,
#   'originalPrice': 19000,
#   'color': '53 Dark 다크',
#   'category': '홈 > FACE',
#   'brand': 'bourjois',
#   'volume': '7.8ml'}]
# [{'name': 'NEW 헬씨 믹스 생과일 파운데이션',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=464&cate_no=24&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201701/464_shop1_573121.jpg'],
#   'salePrice': 35000,
#   'originalPrice': 35000,
#   'color': '50 Rose Ivory 로즈 아이보리',
#   'category': '홈 > FACE',
#   'brand': 'bourjois',
#   'volume': '30ml'},
#  {'name': 'NEW 헬씨 믹스 생과일 파운데이션',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=464&cate_no=24&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201701/464_shop1_573121.jpg'],
#   'salePrice': 35000,
#   'originalPrice': 35000,
#   'color': '51 Light Vanilla 라이트 바닐라',
#   'category': '홈 > FACE',
#   'brand': 'bourjois',
#   'volume': '30ml'},
#  {'name': 'NEW 헬씨 믹스 생과일 파운데이션',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=464&cate_no=24&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201701/464_shop1_573121.jpg'],
#   'salePrice': 35000,
#   'originalPrice': 35000,
#   'color': '52 Vanilla 바닐라',
#   'category': '홈 > FACE',
#   'brand': 'bourjois',
#   'volume': '30ml'}]
# [{'name': '시티 래디언스 파운데이션',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=420&cate_no=24&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201602/420_shop1_199284.jpg'],
#   'salePrice': 38000,
#   'originalPrice': 38000,
#   'color': '01 로즈 아이보리',
#   'category': '홈 > FACE',
#   'brand': 'bourjois',
#   'volume': '30ml'},
#  {'name': '시티 래디언스 파운데이션',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=420&cate_no=24&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201602/420_shop1_199284.jpg'],
#   'salePrice': 38000,
#   'originalPrice': 38000,
#   'color': '02 바닐라',
#   'category': '홈 > FACE',
#   'brand': 'bourjois',
#   'volume': '30ml'},
#  {'name': '시티 래디언스 파운데이션',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=420&cate_no=24&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201602/420_shop1_199284.jpg'],
#   'salePrice': 38000,
#   'originalPrice': 38000,
#   'color': '03 베이지 라이트',
#   'category': '홈 > FACE',
#   'brand': 'bourjois',
#   'volume': '30ml'}]
# [{'name': '시티 래디언스 컨실러',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=421&cate_no=24&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201602/421_shop1_424830.jpg'],
#   'salePrice': 24000,
#   'originalPrice': 24000,
#   'color': '01 아이보리',
#   'category': '홈 > FACE',
#   'brand': 'bourjois',
#   'volume': '7.8ml'},
#  {'name': '시티 래디언스 컨실러',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=421&cate_no=24&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201602/421_shop1_424830.jpg'],
#   'salePrice': 24000,
#   'originalPrice': 24000,
#   'color': '02 베이지',
#   'category': '홈 > FACE',
#   'brand': 'bourjois',
#   'volume': '7.8ml'},
#  {'name': '시티 래디언스 컨실러',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=421&cate_no=24&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201602/421_shop1_424830.jpg'],
#   'salePrice': 24000,
#   'originalPrice': 24000,
#   'color': '03 다크베이지',
#   'category': '홈 > FACE',
#   'brand': 'bourjois',
#   'volume': '7.8ml'}]
# [{'name': '에어매트 파운데이션',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=400&cate_no=24&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201508/400_shop1_477960.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201508/400_shop1_539447.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201508/400_shop1_669541.jpg'],
#   'salePrice': 38000,
#   'originalPrice': 38000,
#   'color': '01 로즈 아이보리',
#   'category': '홈 > FACE',
#   'brand': 'bourjois',
#   'volume': '30ml'},
#  {'name': '에어매트 파운데이션',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=400&cate_no=24&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201508/400_shop1_477960.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201508/400_shop1_539447.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201508/400_shop1_669541.jpg'],
#   'salePrice': 38000,
#   'originalPrice': 38000,
#   'color': '02 바닐라',
#   'category': '홈 > FACE',
#   'brand': 'bourjois',
#   'volume': '30ml'}]
# [{'name': '헬씨 믹스 세럼 파운데이션',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=316&cate_no=24&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201504/316_shop1_877857.jpg'],
#   'salePrice': 40000,
#   'originalPrice': 40000,
#   'color': '51 바닐라 클레어',
#   'category': '홈 > FACE',
#   'brand': 'bourjois',
#   'volume': '30ml'},
#  {'name': '헬씨 믹스 세럼 파운데이션',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=316&cate_no=24&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201504/316_shop1_877857.jpg'],
#   'salePrice': 40000,
#   'originalPrice': 40000,
#   'color': '52 바닐라',
#   'category': '홈 > FACE',
#   'brand': 'bourjois',
#   'volume': '30ml'}]
# [{'name': '실크 에디션 콤팩트 파우더',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=336&cate_no=24&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201410/336_shop1_709133.jpg'],
#   'salePrice': 31000,
#   'originalPrice': 31000,
#   'color': '51 Porcelaine',
#   'category': '홈 > FACE',
#   'brand': 'bourjois',
#   'volume': '9g'},
#  {'name': '실크 에디션 콤팩트 파우더',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=336&cate_no=24&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201410/336_shop1_709133.jpg'],
#   'salePrice': 31000,
#   'originalPrice': 31000,
#   'color': '52 Vanille',
#   'category': '홈 > FACE',
#   'brand': 'bourjois',
#   'volume': '9g'},
#  {'name': '실크 에디션 콤팩트 파우더',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=336&cate_no=24&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201410/336_shop1_709133.jpg'],
#   'salePrice': 31000,
#   'originalPrice': 31000,
#   'color': '54 Beige Rose',
#   'category': '홈 > FACE',
#   'brand': 'bourjois',
#   'volume': '9g'}]
# [{'name': '자바 파우더(뿌드르 드 리즈 자바 파우더)',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=311&cate_no=24&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/311_shop1_797454.jpg'],
#   'salePrice': 36000,
#   'originalPrice': 36000,
#   'color': '#',
#   'category': '홈 > FACE',
#   'brand': 'bourjois',
#   'volume': '3.5g'}]
# [{'name': '123 퍼펙트 CC 아이 크림',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=270&cate_no=24&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/270_shop1_952179.jpg'],
#   'salePrice': 28000,
#   'originalPrice': 28000,
#   'color': '21 아이보리',
#   'category': '홈 > FACE',
#   'brand': 'bourjois',
#   'volume': '1.5ml'},
#  {'name': '123 퍼펙트 CC 아이 크림',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=270&cate_no=24&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/270_shop1_952179.jpg'],
#   'salePrice': 28000,
#   'originalPrice': 28000,
#   'color': '22 베이지 끌레르',
#   'category': '홈 > FACE',
#   'brand': 'bourjois',
#   'volume': '1.5ml'}]
# [{'name': '123 퍼펙트 CC크림',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=272&cate_no=24&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201503/272_shop1_542465.jpg'],
#   'salePrice': 36000,
#   'originalPrice': 36000,
#   'color': '31 아이보리',
#   'category': '홈 > FACE',
#   'brand': 'bourjois',
#   'volume': '30ml'},
#  {'name': '123 퍼펙트 CC크림',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=272&cate_no=24&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201503/272_shop1_542465.jpg'],
#   'salePrice': 36000,
#   'originalPrice': 36000,
#   'color': '32 베이지 끌레르',
#   'category': '홈 > FACE',
#   'brand': 'bourjois',
#   'volume': '30ml'}]
# [{'name': '해피라이트 세럼 프라이머 (매트/뤼미에르)',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=274&cate_no=24&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201412/274_shop1_650959.jpg'],
#   'salePrice': 30000,
#   'originalPrice': 30000,
#   'color': '매트',
#   'category': '홈 > FACE',
#   'brand': 'bourjois',
#   'volume': '15ml'},
#  {'name': '해피라이트 세럼 프라이머 (매트/뤼미에르)',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=274&cate_no=24&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201412/274_shop1_650959.jpg'],
#   'salePrice': 30000,
#   'originalPrice': 30000,
#   'color': '뤼미에르',
#   'category': '홈 > FACE',
#   'brand': 'bourjois',
#   'volume': '15ml'}]
# [{'name': '헬씨 믹스 컨실러',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=307&cate_no=24&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/307_shop1_849449.jpg'],
#   'salePrice': 28000,
#   'originalPrice': 28000,
#   'color': '51 에끌라 끌레어',
#   'category': '홈 > FACE',
#   'brand': 'bourjois',
#   'volume': '10ml'},
#  {'name': '헬씨 믹스 컨실러',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=307&cate_no=24&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/307_shop1_849449.jpg'],
#   'salePrice': 28000,
#   'originalPrice': 28000,
#   'color': '52 에끌라 미디움',
#   'category': '홈 > FACE',
#   'brand': 'bourjois',
#   'volume': '10ml'}]
# [{'name': '스틱 안티세른 코렉터',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=308&cate_no=24&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/308_shop1_176218.jpg'],
#   'salePrice': 24000,
#   'originalPrice': 24000,
#   'color': '71 베이지 끌레르',
#   'category': '홈 > FACE',
#   'brand': 'bourjois',
#   'volume': '2.5g'},
#  {'name': '스틱 안티세른 코렉터',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=308&cate_no=24&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/308_shop1_176218.jpg'],
#   'salePrice': 24000,
#   'originalPrice': 24000,
#   'color': '72 베이지 로제',
#   'category': '홈 > FACE',
#   'brand': 'bourjois',
#   'volume': '2.5g'}]
# [{'name': '헬씨 믹스 밸런스 프레스드 파우더',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=271&cate_no=24&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/271_shop1_943365.jpg'],
#   'salePrice': 28000,
#   'originalPrice': 28000,
#   'color': '52 바닐라',
#   'category': '홈 > FACE',
#   'brand': 'bourjois',
#   'volume': '9g'},
#  {'name': '헬씨 믹스 밸런스 프레스드 파우더',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=271&cate_no=24&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/271_shop1_943365.jpg'],
#   'salePrice': 28000,
#   'originalPrice': 28000,
#   'color': '53 베이지 클레어',
#   'category': '홈 > FACE',
#   'brand': 'bourjois',
#   'volume': '9g'}]
# [{'name': '실크 에디션 터치 업 파우더',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=481&cate_no=24&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201703/481_shop1_400554.jpg'],
#   'salePrice': 26000,
#   'originalPrice': 26000,
#   'color': '#',
#   'category': '홈 > FACE',
#   'brand': 'bourjois',
#   'volume': '7.5g'}]
# [{'name': '해피라이트 컨실러',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=281&cate_no=24&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/281_shop1_367774.jpg'],
#   'salePrice': 24000,
#   'originalPrice': 24000,
#   'color': '21 아이보리',
#   'category': '홈 > FACE',
#   'brand': 'bourjois',
#   'volume': '2.5g'},
#  {'name': '해피라이트 컨실러',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=281&cate_no=24&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/281_shop1_367774.jpg'],
#   'salePrice': 24000,
#   'originalPrice': 24000,
#   'color': '22 베이지 로제',
#   'category': '홈 > FACE',
#   'brand': 'bourjois',
#   'volume': '2.5g'}]
# [{'name': '크렘 무쌍뜨 데마끼앙뜨',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=392&cate_no=24&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201507/392_shop1_689223.jpg'],
#   'salePrice': 22000,
#   'originalPrice': 22000,
#   'color': '#',
#   'category': '홈 > FACE',
#   'brand': 'bourjois',
#   'volume': '150ml'}]
# [{'name': '오 미셀레르 익스프레스',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=393&cate_no=24&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201507/393_shop1_627971.jpg'],
#   'salePrice': 22000,
#   'originalPrice': 22000,
#   'color': '#',
#   'category': '홈 > FACE',
#   'brand': 'bourjois',
#   'volume': '250ml'}]
# [{'name': '듀오 초콜릿 하이라이터 & 브론저',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=381&cate_no=24&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201506/381_shop1_880348.jpg'],
#   'salePrice': 30000,
#   'originalPrice': 30000,
#   'color': '#',
#   'category': '홈 > FACE',
#   'brand': 'bourjois',
#   'volume': '16.5g'}]
# [{'name': '플라워 퍼펙션 스무딩 프라이머',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=312&cate_no=24&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/312_shop1_440195.jpg'],
#   'salePrice': 24000,
#   'originalPrice': 24000,
#   'color': '#',
#   'category': '홈 > FACE',
#   'brand': 'bourjois',
#   'volume': '7ml'}]
# [{'name': '아쿠아 블러쉬 12hr',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=379&cate_no=25&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201506/379_shop1_205413.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201506/379_shop1_264646.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201506/379_shop1_559525.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201506/379_shop1_783693.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201506/379_shop1_236604.jpg'],
#   'salePrice': 24000,
#   'originalPrice': 24000,
#   'color': '01 잉게 누드 (-7,200원)',
#   'category': '홈 > CHEEK',
#   'brand': 'bourjois',
#   'volume': '7.7ml'},
#  {'name': '아쿠아 블러쉬 12hr',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=379&cate_no=25&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201506/379_shop1_205413.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201506/379_shop1_264646.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201506/379_shop1_559525.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201506/379_shop1_783693.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201506/379_shop1_236604.jpg'],
#   'salePrice': 24000,
#   'originalPrice': 24000,
#   'color': '02 코코리코레일 (-7,200원)',
#   'category': '홈 > CHEEK',
#   'brand': 'bourjois',
#   'volume': '7.7ml'},
#  {'name': '아쿠아 블러쉬 12hr',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=379&cate_no=25&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201506/379_shop1_205413.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201506/379_shop1_264646.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201506/379_shop1_559525.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201506/379_shop1_783693.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201506/379_shop1_236604.jpg'],
#   'salePrice': 24000,
#   'originalPrice': 24000,
#   'color': '03 핑크 트와이스',
#   'category': '홈 > CHEEK',
#   'brand': 'bourjois',
#   'volume': '7.7ml'},
#  {'name': '아쿠아 블러쉬 12hr',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=379&cate_no=25&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201506/379_shop1_205413.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201506/379_shop1_264646.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201506/379_shop1_559525.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201506/379_shop1_783693.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201506/379_shop1_236604.jpg'],
#   'salePrice': 24000,
#   'originalPrice': 24000,
#   'color': '04 베리 나이스',
#   'category': '홈 > CHEEK',
#   'brand': 'bourjois',
#   'volume': '7.7ml'}]
# [{'name': '블러쉬',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=287&cate_no=25&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201501/287_shop1_459627.jpg'],
#   'salePrice': 23000,
#   'originalPrice': 23000,
#   'color': '10 샤떼뉴 도레',
#   'category': '홈 > CHEEK',
#   'brand': 'bourjois',
#   'volume': '2.5g'},
#  {'name': '블러쉬',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=287&cate_no=25&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201501/287_shop1_459627.jpg'],
#   'salePrice': 23000,
#   'originalPrice': 23000,
#   'color': '15 로즈 에끌라',
#   'category': '홈 > CHEEK',
#   'brand': 'bourjois',
#   'volume': '2.5g'},
#  {'name': '블러쉬',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=287&cate_no=25&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201501/287_shop1_459627.jpg'],
#   'salePrice': 23000,
#   'originalPrice': 23000,
#   'color': '16 로즈 쿠 드 푸드르',
#   'category': '홈 > CHEEK',
#   'brand': 'bourjois',
#   'volume': '2.5g'},
#  {'name': '블러쉬',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=287&cate_no=25&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201501/287_shop1_459627.jpg'],
#   'salePrice': 23000,
#   'originalPrice': 23000,
#   'color': '32 앙브르 도르',
#   'category': '홈 > CHEEK',
#   'brand': 'bourjois',
#   'volume': '2.5g'},
#  {'name': '블러쉬',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=287&cate_no=25&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201501/287_shop1_459627.jpg'],
#   'salePrice': 23000,
#   'originalPrice': 23000,
#   'color': '33 릴라 도르',
#   'category': '홈 > CHEEK',
#   'brand': 'bourjois',
#   'volume': '2.5g'},
#  {'name': '블러쉬',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=287&cate_no=25&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201501/287_shop1_459627.jpg'],
#   'salePrice': 23000,
#   'originalPrice': 23000,
#   'color': '34 로즈 도르',
#   'category': '홈 > CHEEK',
#   'brand': 'bourjois',
#   'volume': '2.5g'},
#  {'name': '블러쉬',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=287&cate_no=25&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201501/287_shop1_459627.jpg'],
#   'salePrice': 23000,
#   'originalPrice': 23000,
#   'color': '41 헬씨 믹스',
#   'category': '홈 > CHEEK',
#   'brand': 'bourjois',
#   'volume': '2.5g'},
#  {'name': '블러쉬',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=287&cate_no=25&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201501/287_shop1_459627.jpg'],
#   'salePrice': 23000,
#   'originalPrice': 23000,
#   'color': '42 로즈 블라썸',
#   'category': '홈 > CHEEK',
#   'brand': 'bourjois',
#   'volume': '2.5g'},
#  {'name': '블러쉬',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=287&cate_no=25&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201501/287_shop1_459627.jpg'],
#   'salePrice': 23000,
#   'originalPrice': 23000,
#   'color': '43 코랄 템테이션',
#   'category': '홈 > CHEEK',
#   'brand': 'bourjois',
#   'volume': '2.5g'},
#  {'name': '블러쉬',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=287&cate_no=25&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201501/287_shop1_459627.jpg'],
#   'salePrice': 23000,
#   'originalPrice': 23000,
#   'color': '48 로즈 브륀',
#   'category': '홈 > CHEEK',
#   'brand': 'bourjois',
#   'volume': '2.5g'},
#  {'name': '블러쉬',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=287&cate_no=25&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201501/287_shop1_459627.jpg'],
#   'salePrice': 23000,
#   'originalPrice': 23000,
#   'color': '54 로즈 프리송',
#   'category': '홈 > CHEEK',
#   'brand': 'bourjois',
#   'volume': '2.5g'},
#  {'name': '블러쉬',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=287&cate_no=25&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201501/287_shop1_459627.jpg'],
#   'salePrice': 23000,
#   'originalPrice': 23000,
#   'color': '72 터멧',
#   'category': '홈 > CHEEK',
#   'brand': 'bourjois',
#   'volume': '2.5g'},
#  {'name': '블러쉬',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=287&cate_no=25&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201501/287_shop1_459627.jpg'],
#   'salePrice': 23000,
#   'originalPrice': 23000,
#   'color': '74 로즈 앙브르',
#   'category': '홈 > CHEEK',
#   'brand': 'bourjois',
#   'volume': '2.5g'},
#  {'name': '블러쉬',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=287&cate_no=25&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201501/287_shop1_459627.jpg'],
#   'salePrice': 23000,
#   'originalPrice': 23000,
#   'color': '85 시에나',
#   'category': '홈 > CHEEK',
#   'brand': 'bourjois',
#   'volume': '2.5g'},
#  {'name': '블러쉬',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=287&cate_no=25&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201501/287_shop1_459627.jpg'],
#   'salePrice': 23000,
#   'originalPrice': 23000,
#   'color': '92 상탈',
#   'category': '홈 > CHEEK',
#   'brand': 'bourjois',
#   'volume': '2.5g'},
#  {'name': '블러쉬',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=287&cate_no=25&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201501/287_shop1_459627.jpg'],
#   'salePrice': 23000,
#   'originalPrice': 23000,
#   'color': '95 로즈 드 쟈스프',
#   'category': '홈 > CHEEK',
#   'brand': 'bourjois',
#   'volume': '2.5g'}]
# [{'name': '새틴 &메탈 에디션 아이섀도우',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=519&cate_no=26&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201808/3f3e858cd4fae3f9facf99292d39d1f8.jpg'],
#   'salePrice': 23000,
#   'originalPrice': 23000,
#   'color': '01 베이지셀러',
#   'category': '홈 > EYE',
#   'brand': 'bourjois',
#   'volume': '8ml'},
#  {'name': '새틴 &메탈 에디션 아이섀도우',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=519&cate_no=26&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201808/3f3e858cd4fae3f9facf99292d39d1f8.jpg'],
#   'salePrice': 23000,
#   'originalPrice': 23000,
#   'color': '02 오드로즈',
#   'category': '홈 > EYE',
#   'brand': 'bourjois',
#   'volume': '8ml'},
#  {'name': '새틴 &메탈 에디션 아이섀도우',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=519&cate_no=26&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201808/3f3e858cd4fae3f9facf99292d39d1f8.jpg'],
#   'salePrice': 23000,
#   'originalPrice': 23000,
#   'color': '03 무브 유어 바디',
#   'category': '홈 > EYE',
#   'brand': 'bourjois',
#   'volume': '8ml'},
#  {'name': '새틴 &메탈 에디션 아이섀도우',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=519&cate_no=26&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201808/3f3e858cd4fae3f9facf99292d39d1f8.jpg'],
#   'salePrice': 23000,
#   'originalPrice': 23000,
#   'color': '04 아브라카다 브라운',
#   'category': '홈 > EYE',
#   'brand': 'bourjois',
#   'volume': '8ml'},
#  {'name': '새틴 &메탈 에디션 아이섀도우',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=519&cate_no=26&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201808/3f3e858cd4fae3f9facf99292d39d1f8.jpg'],
#   'salePrice': 23000,
#   'originalPrice': 23000,
#   'color': '05 라라방드',
#   'category': '홈 > EYE',
#   'brand': 'bourjois',
#   'volume': '8ml'},
#  {'name': '새틴 &메탈 에디션 아이섀도우',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=519&cate_no=26&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201808/3f3e858cd4fae3f9facf99292d39d1f8.jpg'],
#   'salePrice': 23000,
#   'originalPrice': 23000,
#   'color': '06 드라이브 미 그레이지',
#   'category': '홈 > EYE',
#   'brand': 'bourjois',
#   'volume': '8ml'},
#  {'name': '새틴 &메탈 에디션 아이섀도우',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=519&cate_no=26&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201808/3f3e858cd4fae3f9facf99292d39d1f8.jpg'],
#   'salePrice': 23000,
#   'originalPrice': 23000,
#   'color': '07 오드 커먼',
#   'category': '홈 > EYE',
#   'brand': 'bourjois',
#   'volume': '8ml'},
#  {'name': '새틴 &메탈 에디션 아이섀도우',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=519&cate_no=26&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201808/3f3e858cd4fae3f9facf99292d39d1f8.jpg'],
#   'salePrice': 23000,
#   'originalPrice': 23000,
#   'color': '08 아이언 우먼',
#   'category': '홈 > EYE',
#   'brand': 'bourjois',
#   'volume': '8ml'}]
# [{'name': 'B)Brow Pomade',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=517&cate_no=26&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201806/517_shop1_15302537924969.jpg'],
#   'salePrice': 19000,
#   'originalPrice': 19000,
#   'color': 'T01 Blond',
#   'category': '홈 > EYE',
#   'brand': 'bourjois',
#   'volume': '3.25g'},
#  {'name': 'B)Brow Pomade',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=517&cate_no=26&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201806/517_shop1_15302537924969.jpg'],
#   'salePrice': 19000,
#   'originalPrice': 19000,
#   'color': 'T02 Chatain',
#   'category': '홈 > EYE',
#   'brand': 'bourjois',
#   'volume': '3.25g'},
#  {'name': 'B)Brow Pomade',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=517&cate_no=26&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201806/517_shop1_15302537924969.jpg'],
#   'salePrice': 19000,
#   'originalPrice': 19000,
#   'color': 'T03 Brun',
#   'category': '홈 > EYE',
#   'brand': 'bourjois',
#   'volume': '3.25g'}]
# [{'name': '라이너 펠트 슬림',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=485&cate_no=26&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201706/485_shop1_954786.jpg'],
#   'salePrice': 27000,
#   'originalPrice': 27000,
#   'color': '16. 느와르',
#   'category': '홈 > EYE',
#   'brand': 'bourjois',
#   'volume': '#'},
#  {'name': '라이너 펠트 슬림',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=485&cate_no=26&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201706/485_shop1_954786.jpg'],
#   'salePrice': 27000,
#   'originalPrice': 27000,
#   'color': '17. 울트라블랙',
#   'category': '홈 > EYE',
#   'brand': 'bourjois',
#   'volume': '#'}]
# [{'name': '팔레트 레 누드',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=459&cate_no=26&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201702/459_shop1_613617.png'],
#   'salePrice': 32000,
#   'originalPrice': 32000,
#   'color': '#',
#   'category': '홈 > EYE',
#   'brand': 'bourjois',
#   'volume': '4.5g'}]
# [{'name': '볼륨 리빌 마스카라',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=427&cate_no=26&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201610/427_shop1_599677.jpg'],
#   'salePrice': 22000,
#   'originalPrice': 22000,
#   'color': '#',
#   'category': '홈 > EYE',
#   'brand': 'bourjois',
#   'volume': '7.5ml'}]
# [{'name': '스모키 스토리 아이섀도',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=338&cate_no=26&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201601/338_shop1_813746.jpg'],
#   'salePrice': 24000,
#   'originalPrice': 24000,
#   'color': '02 오버로즈',
#   'category': '홈 > EYE',
#   'brand': 'bourjois',
#   'volume': '3.5g'},
#  {'name': '스모키 스토리 아이섀도',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=338&cate_no=26&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201601/338_shop1_813746.jpg'],
#   'salePrice': 24000,
#   'originalPrice': 24000,
#   'color': '03  아이 러브 블루',
#   'category': '홈 > EYE',
#   'brand': 'bourjois',
#   'volume': '3.5g'},
#  {'name': '스모키 스토리 아이섀도',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=338&cate_no=26&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201601/338_shop1_813746.jpg'],
#   'salePrice': 24000,
#   'originalPrice': 24000,
#   'color': '04 락 디스 카키',
#   'category': '홈 > EYE',
#   'brand': 'bourjois',
#   'volume': '3.5g'},
#  {'name': '스모키 스토리 아이섀도',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=338&cate_no=26&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201601/338_shop1_813746.jpg'],
#   'salePrice': 24000,
#   'originalPrice': 24000,
#   'color': '06 업사이드 브라운',
#   'category': '홈 > EYE',
#   'brand': 'bourjois',
#   'volume': '3.5g'},
#  {'name': '스모키 스토리 아이섀도',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=338&cate_no=26&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201601/338_shop1_813746.jpg'],
#   'salePrice': 24000,
#   'originalPrice': 24000,
#   'color': '08 오션 오브레션',
#   'category': '홈 > EYE',
#   'brand': 'bourjois',
#   'volume': '3.5g'},
#  {'name': '스모키 스토리 아이섀도',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=338&cate_no=26&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201601/338_shop1_813746.jpg'],
#   'salePrice': 24000,
#   'originalPrice': 24000,
#   'color': '09 그레이지 인 러브',
#   'category': '홈 > EYE',
#   'brand': 'bourjois',
#   'volume': '3.5g'},
#  {'name': '스모키 스토리 아이섀도',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=338&cate_no=26&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201601/338_shop1_813746.jpg'],
#   'salePrice': 24000,
#   'originalPrice': 24000,
#   'color': '10 웰컴 블랙',
#   'category': '홈 > EYE',
#   'brand': 'bourjois',
#   'volume': '3.5g'},
#  {'name': '스모키 스토리 아이섀도',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=338&cate_no=26&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201601/338_shop1_813746.jpg'],
#   'salePrice': 24000,
#   'originalPrice': 24000,
#   'color': '12 사우 몬데인',
#   'category': '홈 > EYE',
#   'brand': 'bourjois',
#   'volume': '3.5g'},
#  {'name': '스모키 스토리 아이섀도',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=338&cate_no=26&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201601/338_shop1_813746.jpg'],
#   'salePrice': 24000,
#   'originalPrice': 24000,
#   'color': '13 토프씨메',
#   'category': '홈 > EYE',
#   'brand': 'bourjois',
#   'volume': '3.5g'},
#  {'name': '스모키 스토리 아이섀도',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=338&cate_no=26&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201601/338_shop1_813746.jpg'],
#   'salePrice': 24000,
#   'originalPrice': 24000,
#   'color': '14 톰베 데 누드',
#   'category': '홈 > EYE',
#   'brand': 'bourjois',
#   'volume': '3.5g'}]
# [{'name': '라이너 스타일로 울트라 블랙',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=405&cate_no=26&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201510/405_shop1_788370.jpg'],
#   'salePrice': 27000,
#   'originalPrice': 27000,
#   'color': '#',
#   'category': '홈 > EYE',
#   'brand': 'bourjois',
#   'volume': '0.28g'}]
# [{'name': 'NEW 더 리틀 라운드팟 아이섀도우',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=401&cate_no=26&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201702/401_shop1_108429.png',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_750516.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_238745.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_356357.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_498021.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_807814.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_723793.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_458883.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_106230.jpg'],
#   'salePrice': 21000,
#   'originalPrice': 21000,
#   'color': '01 잉게누드',
#   'category': '홈 > EYE',
#   'brand': 'bourjois',
#   'volume': '1.7g'},
#  {'name': 'NEW 더 리틀 라운드팟 아이섀도우',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=401&cate_no=26&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201702/401_shop1_108429.png',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_750516.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_238745.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_356357.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_498021.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_807814.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_723793.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_458883.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_106230.jpg'],
#   'salePrice': 21000,
#   'originalPrice': 21000,
#   'color': '02 제네로제',
#   'category': '홈 > EYE',
#   'brand': 'bourjois',
#   'volume': '1.7g'},
#  {'name': 'NEW 더 리틀 라운드팟 아이섀도우',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=401&cate_no=26&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201702/401_shop1_108429.png',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_750516.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_238745.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_356357.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_498021.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_807814.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_723793.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_458883.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_106230.jpg'],
#   'salePrice': 21000,
#   'originalPrice': 21000,
#   'color': '03 오리지날',
#   'category': '홈 > EYE',
#   'brand': 'bourjois',
#   'volume': '1.7g'},
#  {'name': 'NEW 더 리틀 라운드팟 아이섀도우',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=401&cate_no=26&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201702/401_shop1_108429.png',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_750516.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_238745.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_356357.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_498021.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_807814.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_723793.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_458883.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_106230.jpg'],
#   'salePrice': 21000,
#   'originalPrice': 21000,
#   'color': '04 에모바',
#   'category': '홈 > EYE',
#   'brand': 'bourjois',
#   'volume': '1.7g'},
#  {'name': 'NEW 더 리틀 라운드팟 아이섀도우',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=401&cate_no=26&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201702/401_shop1_108429.png',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_750516.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_238745.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_356357.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_498021.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_807814.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_723793.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_458883.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_106230.jpg'],
#   'salePrice': 21000,
#   'originalPrice': 21000,
#   'color': '05 무비스타',
#   'category': '홈 > EYE',
#   'brand': 'bourjois',
#   'volume': '1.7g'},
#  {'name': 'NEW 더 리틀 라운드팟 아이섀도우',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=401&cate_no=26&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201702/401_shop1_108429.png',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_750516.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_238745.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_356357.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_498021.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_807814.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_723793.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_458883.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_106230.jpg'],
#   'salePrice': 21000,
#   'originalPrice': 21000,
#   'color': '06 유토피크',
#   'category': '홈 > EYE',
#   'brand': 'bourjois',
#   'volume': '1.7g'},
#  {'name': 'NEW 더 리틀 라운드팟 아이섀도우',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=401&cate_no=26&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201702/401_shop1_108429.png',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_750516.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_238745.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_356357.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_498021.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_807814.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_723793.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_458883.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_106230.jpg'],
#   'salePrice': 21000,
#   'originalPrice': 21000,
#   'color': '07 브룬드폴리',
#   'category': '홈 > EYE',
#   'brand': 'bourjois',
#   'volume': '1.7g'},
#  {'name': 'NEW 더 리틀 라운드팟 아이섀도우',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=401&cate_no=26&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201702/401_shop1_108429.png',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_750516.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_238745.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_356357.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_498021.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_807814.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_723793.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_458883.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_106230.jpg'],
#   'salePrice': 21000,
#   'originalPrice': 21000,
#   'color': '08 녹땀브룬',
#   'category': '홈 > EYE',
#   'brand': 'bourjois',
#   'volume': '1.7g'},
#  {'name': 'NEW 더 리틀 라운드팟 아이섀도우',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=401&cate_no=26&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201702/401_shop1_108429.png',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_750516.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_238745.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_356357.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_498021.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_807814.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_723793.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_458883.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_106230.jpg'],
#   'salePrice': 21000,
#   'originalPrice': 21000,
#   'color': '09 뤼네르',
#   'category': '홈 > EYE',
#   'brand': 'bourjois',
#   'volume': '1.7g'},
#  {'name': 'NEW 더 리틀 라운드팟 아이섀도우',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=401&cate_no=26&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201702/401_shop1_108429.png',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_750516.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_238745.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_356357.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_498021.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_807814.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_723793.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_458883.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_106230.jpg'],
#   'salePrice': 21000,
#   'originalPrice': 21000,
#   'color': '10 엥세지 사블',
#   'category': '홈 > EYE',
#   'brand': 'bourjois',
#   'volume': '1.7g'},
#  {'name': 'NEW 더 리틀 라운드팟 아이섀도우',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=401&cate_no=26&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201702/401_shop1_108429.png',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_750516.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_238745.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_356357.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_498021.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_807814.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_723793.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_458883.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_106230.jpg'],
#   'salePrice': 21000,
#   'originalPrice': 21000,
#   'color': '11 아 로 드 로즈',
#   'category': '홈 > EYE',
#   'brand': 'bourjois',
#   'volume': '1.7g'},
#  {'name': 'NEW 더 리틀 라운드팟 아이섀도우',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=401&cate_no=26&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201702/401_shop1_108429.png',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_750516.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_238745.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_356357.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_498021.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_807814.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_723793.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_458883.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_106230.jpg'],
#   'salePrice': 21000,
#   'originalPrice': 21000,
#   'color': '12 엑스트라 오르 디네르',
#   'category': '홈 > EYE',
#   'brand': 'bourjois',
#   'volume': '1.7g'},
#  {'name': 'NEW 더 리틀 라운드팟 아이섀도우',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=401&cate_no=26&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201702/401_shop1_108429.png',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_750516.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_238745.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_356357.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_498021.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_807814.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_723793.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_458883.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_106230.jpg'],
#   'salePrice': 21000,
#   'originalPrice': 21000,
#   'color': '13 엑스트라 베흐티',
#   'category': '홈 > EYE',
#   'brand': 'bourjois',
#   'volume': '1.7g'},
#  {'name': 'NEW 더 리틀 라운드팟 아이섀도우',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=401&cate_no=26&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201702/401_shop1_108429.png',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_750516.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_238745.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_356357.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_498021.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_807814.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_723793.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_458883.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_106230.jpg'],
#   'salePrice': 21000,
#   'originalPrice': 21000,
#   'color': '14 베흐 티지너즈',
#   'category': '홈 > EYE',
#   'brand': 'bourjois',
#   'volume': '1.7g'},
#  {'name': 'NEW 더 리틀 라운드팟 아이섀도우',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=401&cate_no=26&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201702/401_shop1_108429.png',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_750516.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_238745.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201509/401_shop1_356357.jpg',
# ...
#    'http://bourjois-mall.com/web/product/extra/small/201506/351_shop1_803169.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201506/351_shop1_778662.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201506/351_shop1_913416.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201506/351_shop1_612801.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201506/351_shop1_315296.jpg'],
#   'salePrice': 28000,
#   'originalPrice': 28000,
#   'color': '07 푸치아 페르쉐',
#   'category': '홈 > LIP',
#   'brand': 'bourjois',
#   'volume': '10ml'},
#  {'name': '루즈에디션 아쿠아 락',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=351&cate_no=27&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201502/351_shop1_593232.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201506/351_shop1_926903.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201506/351_shop1_112161.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201506/351_shop1_711594.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201506/351_shop1_803169.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201506/351_shop1_778662.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201506/351_shop1_913416.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201506/351_shop1_612801.jpg',
#    'http://bourjois-mall.com/web/product/extra/small/201506/351_shop1_315296.jpg'],
#   'salePrice': 28000,
#   'originalPrice': 28000,
#   'color': '08 베이브 아이돌 (-5,600원)',
#   'category': '홈 > LIP',
#   'brand': 'bourjois',
#   'volume': '10ml'}]
# [{'name': 'NEW 에페 3D 립글로스',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=280&cate_no=27&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201502/280_shop1_401708.jpg'],
#   'salePrice': 23000,
#   'originalPrice': 23000,
#   'color': '03 립 아카데믹',
#   'category': '홈 > LIP',
#   'brand': 'bourjois',
#   'volume': '5.7ml'},
#  {'name': 'NEW 에페 3D 립글로스',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=280&cate_no=27&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201502/280_shop1_401708.jpg'],
#   'salePrice': 23000,
#   'originalPrice': 23000,
#   'color': '04 립 폴레믹',
#   'category': '홈 > LIP',
#   'brand': 'bourjois',
#   'volume': '5.7ml'},
#  {'name': 'NEW 에페 3D 립글로스',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=280&cate_no=27&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201502/280_shop1_401708.jpg'],
#   'salePrice': 23000,
#   'originalPrice': 23000,
#   'color': '05 히포테틱',
#   'category': '홈 > LIP',
#   'brand': 'bourjois',
#   'volume': '5.7ml'},
#  {'name': 'NEW 에페 3D 립글로스',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=280&cate_no=27&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201502/280_shop1_401708.jpg'],
#   'salePrice': 23000,
#   'originalPrice': 23000,
#   'color': '18 오니릭',
#   'category': '홈 > LIP',
#   'brand': 'bourjois',
#   'volume': '5.7ml'},
#  {'name': 'NEW 에페 3D 립글로스',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=280&cate_no=27&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201502/280_shop1_401708.jpg'],
#   'salePrice': 23000,
#   'originalPrice': 23000,
#   'color': '20 심포닉',
#   'category': '홈 > LIP',
#   'brand': 'bourjois',
#   'volume': '5.7ml'},
#  {'name': 'NEW 에페 3D 립글로스',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=280&cate_no=27&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201502/280_shop1_401708.jpg'],
#   'salePrice': 23000,
#   'originalPrice': 23000,
#   'color': '23 매그니픽',
#   'category': '홈 > LIP',
#   'brand': 'bourjois',
#   'volume': '5.7ml'},
#  {'name': 'NEW 에페 3D 립글로스',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=280&cate_no=27&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201502/280_shop1_401708.jpg'],
#   'salePrice': 23000,
#   'originalPrice': 23000,
#   'color': '29 카라스마틱',
#   'category': '홈 > LIP',
#   'brand': 'bourjois',
#   'volume': '5.7ml'},
#  {'name': 'NEW 에페 3D 립글로스',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=280&cate_no=27&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201502/280_shop1_401708.jpg'],
#   'salePrice': 23000,
#   'originalPrice': 23000,
#   'color': '33 브룬 포에틱',
#   'category': '홈 > LIP',
#   'brand': 'bourjois',
#   'volume': '5.7ml'},
#  {'name': 'NEW 에페 3D 립글로스',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=280&cate_no=27&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201502/280_shop1_401708.jpg'],
#   'salePrice': 23000,
#   'originalPrice': 23000,
#   'color': '46 리릭',
#   'category': '홈 > LIP',
#   'brand': 'bourjois',
#   'volume': '5.7ml'},
#  {'name': 'NEW 에페 3D 립글로스',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=280&cate_no=27&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201502/280_shop1_401708.jpg'],
#   'salePrice': 23000,
#   'originalPrice': 23000,
#   'color': '48 로맨틱',
#   'category': '홈 > LIP',
#   'brand': 'bourjois',
#   'volume': '5.7ml'},
#  {'name': 'NEW 에페 3D 립글로스',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=280&cate_no=27&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201502/280_shop1_401708.jpg'],
#   'salePrice': 23000,
#   'originalPrice': 23000,
#   'color': '51 키메릭',
#   'category': '홈 > LIP',
#   'brand': 'bourjois',
#   'volume': '5.7ml'},
#  {'name': 'NEW 에페 3D 립글로스',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=280&cate_no=27&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201502/280_shop1_401708.jpg'],
#   'salePrice': 23000,
#   'originalPrice': 23000,
#   'color': '52 아이딜릭',
#   'category': '홈 > LIP',
#   'brand': 'bourjois',
#   'volume': '5.7ml'},
#  {'name': 'NEW 에페 3D 립글로스',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=280&cate_no=27&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201502/280_shop1_401708.jpg'],
#   'salePrice': 23000,
#   'originalPrice': 23000,
#   'color': '54 일레토닉',
#   'category': '홈 > LIP',
#   'brand': 'bourjois',
#   'volume': '5.7ml'},
#  {'name': 'NEW 에페 3D 립글로스',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=280&cate_no=27&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201502/280_shop1_401708.jpg'],
#   'salePrice': 23000,
#   'originalPrice': 23000,
#   'color': '57 익세트릭',
#   'category': '홈 > LIP',
#   'brand': 'bourjois',
#   'volume': '5.7ml'},
#  {'name': 'NEW 에페 3D 립글로스',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=280&cate_no=27&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201502/280_shop1_401708.jpg'],
#   'salePrice': 23000,
#   'originalPrice': 23000,
#   'color': '59 알레고리',
#   'category': '홈 > LIP',
#   'brand': 'bourjois',
#   'volume': '5.7ml'},
#  {'name': 'NEW 에페 3D 립글로스',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=280&cate_no=27&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201502/280_shop1_401708.jpg'],
#   'salePrice': 23000,
#   'originalPrice': 23000,
#   'color': '60 오 피리',
#   'category': '홈 > LIP',
#   'brand': 'bourjois',
#   'volume': '5.7ml'}]
# [{'name': '2018 부르조아 TOP 5 기획전',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=529&cate_no=60&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201812/a7284d5ba2c3bc676ba15601166dce29.jpg'],
#   'salePrice': '#',
#   'originalPrice': '#',
#   'color': '#',
#   'category': '홈 > EXCLUSIVE > LINE',
#   'brand': 'bourjois',
#   'volume': '#'}]
# [{'name': 'Velvet Twenty',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=527&cate_no=60&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201811/65780f7b8a18437e4208be0340a39c64.jpg'],
#   'salePrice': 19600,
#   'originalPrice': 28000,
#   'color': '01 펄소네 느 루즈',
#   'category': '홈 > EXCLUSIVE > LINE',
#   'brand': 'bourjois',
#   'volume': '#'},
#  {'name': 'Velvet Twenty',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=527&cate_no=60&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201811/65780f7b8a18437e4208be0340a39c64.jpg'],
#   'salePrice': 19600,
#   'originalPrice': 28000,
#   'color': '02 프람보이즈',
#   'category': '홈 > EXCLUSIVE > LINE',
#   'brand': 'bourjois',
#   'volume': '#'},
#  {'name': 'Velvet Twenty',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=527&cate_no=60&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201811/65780f7b8a18437e4208be0340a39c64.jpg'],
#   'salePrice': 19600,
#   'originalPrice': 28000,
#   'color': '03 핫페퍼',
#   'category': '홈 > EXCLUSIVE > LINE',
#   'brand': 'bourjois',
#   'volume': '#'},
#  {'name': 'Velvet Twenty',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=527&cate_no=60&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201811/65780f7b8a18437e4208be0340a39c64.jpg'],
#   'salePrice': 19600,
#   'originalPrice': 28000,
#   'color': '04 피치클럽',
#   'category': '홈 > EXCLUSIVE > LINE',
#   'brand': 'bourjois',
#   'volume': '#'},
#  {'name': 'Velvet Twenty',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=527&cate_no=60&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201811/65780f7b8a18437e4208be0340a39c64.jpg'],
#   'salePrice': 19600,
#   'originalPrice': 28000,
#   'color': '07 누디스트',
#   'category': '홈 > EXCLUSIVE > LINE',
#   'brand': 'bourjois',
#   'volume': '#'},
#  {'name': 'Velvet Twenty',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=527&cate_no=60&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201811/65780f7b8a18437e4208be0340a39c64.jpg'],
#   'salePrice': 19600,
#   'originalPrice': 28000,
#   'color': '08 그랜드 크루',
#   'category': '홈 > EXCLUSIVE > LINE',
#   'brand': 'bourjois',
#   'volume': '#'},
#  {'name': 'Velvet Twenty',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=527&cate_no=60&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201811/65780f7b8a18437e4208be0340a39c64.jpg'],
#   'salePrice': 19600,
#   'originalPrice': 28000,
#   'color': '09 해피누드이어',
#   'category': '홈 > EXCLUSIVE > LINE',
#   'brand': 'bourjois',
#   'volume': '#'},
#  {'name': 'Velvet Twenty',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=527&cate_no=60&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201811/65780f7b8a18437e4208be0340a39c64.jpg'],
#   'salePrice': 19600,
#   'originalPrice': 28000,
#   'color': '10 돈 핑크오브 잇',
#   'category': '홈 > EXCLUSIVE > LINE',
#   'brand': 'bourjois',
#   'volume': '#'},
#  {'name': 'Velvet Twenty',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=527&cate_no=60&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201811/65780f7b8a18437e4208be0340a39c64.jpg'],
#   'salePrice': 19600,
#   'originalPrice': 28000,
#   'color': '11 쏘햅핑크',
#   'category': '홈 > EXCLUSIVE > LINE',
#   'brand': 'bourjois',
#   'volume': '#'},
#  {'name': 'Velvet Twenty',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=527&cate_no=60&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201811/65780f7b8a18437e4208be0340a39c64.jpg'],
#   'salePrice': 19600,
#   'originalPrice': 28000,
#   'color': '12 보브랭',
#   'category': '홈 > EXCLUSIVE > LINE',
#   'brand': 'bourjois',
#   'volume': '#'},
#  {'name': 'Velvet Twenty',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=527&cate_no=60&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201811/65780f7b8a18437e4208be0340a39c64.jpg'],
#   'salePrice': 19600,
#   'originalPrice': 28000,
#   'color': '13 펀치아',
#   'category': '홈 > EXCLUSIVE > LINE',
#   'brand': 'bourjois',
#   'volume': '#'},
#  {'name': 'Velvet Twenty',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=527&cate_no=60&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201811/65780f7b8a18437e4208be0340a39c64.jpg'],
#   'salePrice': 19600,
#   'originalPrice': 28000,
#   'color': '14 플럼플럼 걸',
#   'category': '홈 > EXCLUSIVE > LINE',
#   'brand': 'bourjois',
#   'volume': '#'},
#  {'name': 'Velvet Twenty',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=527&cate_no=60&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201811/65780f7b8a18437e4208be0340a39c64.jpg'],
#   'salePrice': 19600,
#   'originalPrice': 28000,
#   'color': '15 레드 볼루션',
#   'category': '홈 > EXCLUSIVE > LINE',
#   'brand': 'bourjois',
#   'volume': '#'},
#  {'name': 'Velvet Twenty',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=527&cate_no=60&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201811/65780f7b8a18437e4208be0340a39c64.jpg'],
#   'salePrice': 19600,
#   'originalPrice': 28000,
#   'color': '16 허니무드',
#   'category': '홈 > EXCLUSIVE > LINE',
#   'brand': 'bourjois',
#   'volume': '#'},
#  {'name': 'Velvet Twenty',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=527&cate_no=60&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201811/65780f7b8a18437e4208be0340a39c64.jpg'],
#   'salePrice': 19600,
#   'originalPrice': 28000,
#   'color': '18 잇츠 레딩멘',
#   'category': '홈 > EXCLUSIVE > LINE',
#   'brand': 'bourjois',
#   'volume': '#'},
#  {'name': 'Velvet Twenty',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=527&cate_no=60&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201811/65780f7b8a18437e4208be0340a39c64.jpg'],
#   'salePrice': 19600,
#   'originalPrice': 28000,
#   'color': '19 졸리드뱅',
#   'category': '홈 > EXCLUSIVE > LINE',
#   'brand': 'bourjois',
#   'volume': '#'},
#  {'name': 'Velvet Twenty',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=527&cate_no=60&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201811/65780f7b8a18437e4208be0340a39c64.jpg'],
#   'salePrice': 19600,
#   'originalPrice': 28000,
#   'color': '20 포피데이즈',
#   'category': '홈 > EXCLUSIVE > LINE',
#   'brand': 'bourjois',
#   'volume': '#'},
#  {'name': 'Velvet Twenty',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=527&cate_no=60&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201811/65780f7b8a18437e4208be0340a39c64.jpg'],
#   'salePrice': 19600,
#   'originalPrice': 28000,
#   'color': '22 아브리코케트',
#   'category': '홈 > EXCLUSIVE > LINE',
#   'brand': 'bourjois',
#   'volume': '#'},
#  {'name': 'Velvet Twenty',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=527&cate_no=60&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201811/65780f7b8a18437e4208be0340a39c64.jpg'],
#   'salePrice': 19600,
#   'originalPrice': 28000,
#   'color': '27 카페올레',
#   'category': '홈 > EXCLUSIVE > LINE',
#   'brand': 'bourjois',
#   'volume': '#'},
#  {'name': 'Velvet Twenty',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=527&cate_no=60&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201811/65780f7b8a18437e4208be0340a39c64.jpg'],
#   'salePrice': 19600,
#   'originalPrice': 28000,
#   'color': '28 초코핑크',
#   'category': '홈 > EXCLUSIVE > LINE',
#   'brand': 'bourjois',
#   'volume': '#'}]
# [{'name': '2018 FW 룩북 ② 더스티 로즈 LOOK',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=526&cate_no=81&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201811/9c453d5d47117ae054dd45205aa1785d.jpg'],
#   'salePrice': '#',
#   'originalPrice': '#',
#   'color': '#',
#   'category': '홈 > 2018 > LOOK > BOOK',
#   'brand': 'bourjois',
#   'volume': '#'}]
# [{'name': '2018 FW 룩북 ① 골드 브론즈 LOOK',
#   'url': 'http://bourjois-mall.com/product/detail.html?product_no=523&cate_no=81&display_group=1',
#   'image': ['http://bourjois-mall.com/web/product/small/201809/714ba33770a43860f57442ee66d68705.jpg'],
#   'salePrice': '#',
#   'originalPrice': '#',
#   'color': '#',
#   'category': '홈 > 2018 > LOOK > BOOK',
#   'brand': 'bourjois',
#   'volume': '#'}]

# %%
output = json.dumps(result,ensure_ascii=False, indent='\t')

writeJSON(output, output_name = 'bourjois.json')
